# %% [markdown]
# PPT LINK : https://docs.google.com/presentation/d/1cITP20GhHvuNlKCELmg1Cs9hI0XAlDhZ/edit?usp=sharing&ouid=106702906048169590831&rtpof=true&sd=true

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path="/content/drive/MyDrive/group 5/student-mat.csv"

# %%
import pandas as pd
df=pd.read_csv(path)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.dropna(inplace=True)
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.drop_duplicates()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
desired_cols = ['school','failures','G1','G2','G3']
df1= df[desired_cols]
df1
# Out:
#     school  failures  G1  G2  G3
# 0       GP         0   5   6   6
# 1       GP         0   5   5   6
# 2       GP         3   7   8  10
# 3       GP         0  15  14  15
# 4       GP         0   6  10  10
# ..     ...       ...  ..  ..  ..
# 390     MS         2   9   9   9
# 391     MS         0  14  16  16
# 392     MS         3  10   8   7
# 393     MS         0  11  12  10
# 394     MS         0   8   9   9
#
# [395 rows x 5 columns]

# %% [markdown]
# **MEAN GRADES OF SCHOOLS "GP" AND "MS" USING Bargraph**

# %%
import matplotlib.pyplot as plt
school_means = df1.groupby('school')[['G1', 'G2', 'G3']].mean()
school_means.plot(kind='bar')
plt.xlabel('School')
plt.ylabel('Mean Grade')
plt.title('Mean Grades by School (G1, G2, G3)')
plt.xticks(rotation=0)
plt.legend(title='Grades', labels=['G1', 'G2', 'G3'])
plt.show()

# %% [markdown]
# **Bar Graph of no of Males And Females in Both MS and GP Schools**

# %%
school_sex_counts = df.groupby(['school', 'sex']).size().unstack()
school_sex_counts.plot(kind='bar', stacked=True)
plt.xlabel('School')
plt.ylabel('Count')
plt.title('Counts of Sex by School')
plt.xticks(rotation=0)
plt.legend(title='Sex', labels=['Male', 'Female'])
plt.show()

# %% [markdown]
# **Bar Graph of Schools VS Higher Education (yes or no)**

# %%
grouped_data = df.groupby(['school', 'higher']).size().unstack()
ax = grouped_data.plot(kind='bar', stacked=True)
plt.xlabel('School')
plt.ylabel('Count')
plt.title('Count of Higher by School')
plt.xticks(rotation=0)
plt.legend(title='Higher', labels=['False', 'True'])
plt.show()

# %% [markdown]
# **scatter plot to visualize the relationship between age and sex**

# %%
import seaborn as sns
sns.boxplot(x="age", y="sex", data=df)
plt.show()

# %% [markdown]
# **heatmap to visualize the correlation between grades and studytime**

# %%
cols = ['studytime', 'G1', 'G2', 'G3']
df2 = df[cols]
corr = df2.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# **scatter plot of first period grade (G1) vs final grade (G3)**

# %%
sns.relplot(x='G1', y='G3', data=df)

# %%
plt.hist(df['absences'], bins=20)
plt.xlabel('Number of absences')
plt.ylabel('Frequency')
plt.title('Histogram of Absences')
plt.show()

# %%
sns.countplot(x='Medu', data=df)
plt.show()
sns.countplot(x='Fedu', data=df)
plt.show()

# %%
sns.countplot(x='Mjob', data=df)
plt.show()
sns.countplot(x='Fjob', data=df)
plt.show()

# %%
sns.histplot(x='G1', data=df)
plt.show()
sns.histplot(x='G2', data=df)
plt.show()
sns.histplot(x='G3', data=df)
plt.show()

# %%
binary_cols = ['school', 'sex', 'address', 'famsize', 'Pstatus', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']
for col in binary_cols:
    df[col] = df[col].map({'yes': 1, 'no': 0, 'F': 0, 'M': 1, 'U': 1, 'R': 0, 'LE3': 1, 'GT3': 0, 'T': 1, 'A': 0, 'GP': 1, 'MS': 0})

# %%
df['Mjob'] = df['Mjob'].replace({'teacher': 0, 'health': 0, 'services': 0, 'at_home': 1, 'other': 1})

# %%
df['Fjob'] = df['Fjob'].replace({'teacher': 0, 'health': 0, 'services': 0, 'at_home': 1, 'other': 1})

# %%
reason_dummies = pd.get_dummies(df['reason'], prefix='reason')
df = pd.concat([df, reason_dummies], axis=1)
df = df.drop('reason', axis=1)

# %%
df['guardian'] = df['guardian'].replace({'mother': 0, 'father': 0, 'other': 1})

# %%
df= df.drop(['G1', 'G2'], axis=1)

# %%
df
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         1    0   18        1        0        0     4     4     1     0  ...
# 1         1    0   17        1        0        1     1     1     1     1  ...
# 2         1    0   15        1        1        1     1     1     1     1  ...
# 3         1    0   15        1        0        1     4     2     0     0  ...
# 4         1    0   16        1        0        1     3     3     1     1  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       0    1   20        1        1        0     2     2     0     0  ...
# 391       0    1   17        1        1        1     3     1     0     0  ...
# 392       0    1   21        0        0        1     1     1     1     1  ...
# 393       0    1   18        0        1        1     3     2     0     1  ...
# 394       0    1   19        1        1        1     1     1     1     1  ...
#
# ...

# %%
import numpy as np
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
X = df.drop('G3', axis=1)
y = df['G3']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
coefficients = pd.DataFrame({'Variable': X.columns, 'Coefficient': model.coef_})
print(coefficients)
print('Intercept:', model.intercept_)
r2 = r2_score(y_test, y_pred)
print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 3.1614948583483757
# Mean Squared Error: 16.01961670890061
# Root Mean Squared Error: 4.002451337480646
#              Variable  Coefficient
# 0              school    -0.999684
# 1                 sex     1.238473
# 2                 age    -0.541347
# 3             address     0.128173
# 4             famsize     1.089422
# 5             Pstatus    -0.595809
# 6                Medu     0.317867
# 7                Fedu     0.059714
# 8                Mjob    -0.568490
# 9                Fjob    -0.306127
# 10           guardian    -0.128808
# 11         traveltime    -0.514699
# 12          studytime     0.722139
# 13           failures    -1.621183
# 14          schoolsup    -1.736491
# 15             famsup    -0.845234
# 16               paid     0.319823
# 17         activities    -0.573955
# 18            nursery    -0.148242
# 19             higher     2.912781
# 20           internet    -0.015161
# 21           romantic    -1.197700
# ...

# %%
from sklearn.svm import SVR
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
svm_model = SVR(kernel='linear')
svm_model.fit(X_train_scaled, y_train)
y_pred = svm_model.predict(X_test_scaled)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
coefficients = svm_model.coef_
print('Coefficients:', coefficients)
r2 = r2_score(y_test, y_pred)
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 20.197442148295803
# Coefficients: [[ 1.72558336e-01  2.09410153e-01 -3.58348210e-01  3.05524053e-02
#    1.85411577e-01 -1.78678075e-01  1.55403738e-01 -6.76156298e-02
#   -4.39835253e-02 -6.23129851e-03  3.84374211e-01 -1.94861287e-01
#    3.60178574e-01 -1.21763614e+00 -4.74939022e-01 -6.11720189e-01
#    1.65590256e-01  3.04456562e-02 -3.23802012e-01  2.52726152e-01
#    2.57265997e-01  4.97024500e-02 -3.84270497e-02  3.08109460e-01
#   -4.43075839e-01  1.30868699e-01 -2.04802884e-01  5.41103649e-02
#   -3.26363489e-01 -1.21292124e-01 -1.68966914e-01  1.08799247e-03
#    2.96126098e-01]]
# R-squared: 0.13581895061359084

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
knn_regressor = KNeighborsRegressor(n_neighbors=5) #3,5,7
knn_regressor.fit(X_train , y_train)
y_pred = knn_regressor.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
r2 = r2_score(y_test, y_pred)
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 16.701772151898734
# R-squared: 0.1854799487387867

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
regressor = DecisionTreeRegressor(max_depth=7) #3,5,7
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 18.683665450427945
# R-squared: 0.08882602384802296

# %%
from sklearn.ensemble import RandomForestRegressor
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
rf_model = RandomForestRegressor(n_estimators=100,max_depth=7, random_state=42) #
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
r2 = r2_score(y_test, y_pred)
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 15.139620675397682
# R-squared: 0.3428371779605629

# %%
from sklearn.ensemble import AdaBoostRegressor
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
ada_boost = AdaBoostRegressor(n_estimators=500,learning_rate=0.1, random_state=42)
ada_boost.fit(X_train, y_train)
y_pred = ada_boost.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
r2 = r2_score(y_test, y_pred)
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 18.197466169388367
# R-squared: 0.11253722405563105

# %%
from sklearn.ensemble import GradientBoostingRegressor
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
gb_regressor = GradientBoostingRegressor(n_estimators=500, learning_rate=0.1,max_depth=3,random_state=42)
gb_regressor.fit(X_train, y_train)
predictions = gb_regressor.predict(X_test)
mse = mean_squared_error(y_test,predictions)
print(f'Mean Squared Error: {mse}')
r2 = r2_score(y_test,predictions)
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 15.669047421151928
# R-squared: 0.23584436474065285

# %%
from xgboost import XGBRegressor
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
xgb_model = XGBRegressor(n_estimators=500, learning_rate=0.1,max_depth=3,random_state=42)
xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
r2 = r2_score(y_test,y_pred)
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 16.158555472335447
# R-squared: 0.2119718008404532
